LPR_2_Province.png
#   inflating: ./dataset/province/076สมุทรสงคราม/20220601124439334_317_G1_4_LPRF4_256_LPR_2_Province.png
#   inflating: ./dataset/province/076สมุทรสงคราม/20220601125026765_317_G1_4_LPRF4_293_LPR_2_Province.png
#   inflating: ./dataset/province/076สมุทรสงคราม/20220601153755222_317_G1_1_LPRF1_134_LPR_2_Province.png
#   inflating: ./dataset/province/076สมุทรสงคราม/20220601153833977_317_G1_3_LPRF3_394_LPR_2_Province.png
#   inflating: ./dataset/province/076สมุทรสงคราม/20220602092336931_317_G1_4_LPRF4_101_LPR_2_Province.png
#   inflating: ./dataset/province/076สมุทรสงคราม/20220602132943121_317_G1_3_LPRF3_247_LPR_2_Province.png
#   inflating: ./dataset/province/076สมุทรสงคราม/20220602143310878_317_G1_2_LPRF2_181_LPR_2_Province.png
#   inflating: ./dataset/province/076สมุทรสงคราม/20220602151054171_317_G1_1_LPRF1_43_LPR_2_Province.png
#   inflating: ./dataset/province/076สมุทรสงคราม/20220602232916633_317_G1_4_LPRF4_77_LPR_2_Province.png
#    creating: ./dataset/province/077เบตง/
#   inflating: ./dataset/province/077เบตง/1120781-img.tfwgog.1015r.opsd00p.jpg_Province.png
#   inflating: ./dataset/province/077เบตง/20220114c81e728d9d4c2f636f067f89cc14862c143308.jpg_Province.png
#   inflating: ./dataset/province/077เบตง/20220601144024688_317_G1_2_LPRF2_185_LPR_2_Province.png
#   inflating: ./dataset/province/077เบตง/20220602130952203_317_G1_2_LPRF2_46_LPR_2_Province.png
#   inflating: ./dataset/province/077เบตง/20220602211238778_317_G1_4_LPRF4_63_LPR_2_Province.png
#   inflating: ./dataset/province/077เบตง/2735832556.jpg_Province.png
#   inflating: ./dataset/province/077เบตง/559000009630804.jpg_Province.png
#   inflating: ./dataset/province/077เบตง/ESfu_kAUwAAxrNB.jpg_Province.png
#   inflating: ./dataset/province/077เบตง/Screenshot 2025-02-04 093629.png

# %%
# Add empty folder check to ImageFolder
class CustomImageFolder(datasets.ImageFolder):
    def __init__(self, root, transform=None):
        try:
            super().__init__(root=root, transform=transform)
        except FileNotFoundError as e:
            print(f"Warning: {e}")
            print("Continuing with available classes...")
            super().__init__(root=root, transform=transform, is_valid_file=lambda x: True, allow_empty=True)

# %%
training_set_path = "./dataset/province"

train_split = 0.8
full_training_set = CustomImageFolder(root=training_set_path, transform=transform)
train_size = int(train_split * len(full_training_set))
test_size = len(full_training_set) - train_size
training_set, validation_set = torch.utils.data.random_split(
    full_training_set, [train_size, test_size]
)

training_loader = torch.utils.data.DataLoader(
    training_set, batch_size=BATCH_SIZE, shuffle=True
)
validation_loader = torch.utils.data.DataLoader(
    validation_set, batch_size=BATCH_SIZE, shuffle=False
)

print("Training set has {} instances".format(len(training_set)))
print("Validation set has {} instances".format(len(validation_set)))
# Out:
# Training set has 3261 instances
# Validation set has 816 instances

# %%
class_labels = full_training_set.classes
class_labels_index = full_training_set.class_to_idx
print("Number of Classes:", len(class_labels))
print("Class Labels:", class_labels)
print("Class Labels Index:", class_labels_index)
# Out:
# Number of Classes: 78
# Class Labels: ['000เชียงใหม่', '001นครราชสีมา', '002กาญจนบุรี', '003ตาก', '004อุบลราชธานี', '005สุราษฎร์ธานี', '006ชัยภูมิ', '007แม่ฮ่องสอน', '008เพชรบูรณ์', '009ลำปาง', '010อุดรธานี', '011เชียงราย', '012น่าน', '013เลย', '014ขอนแก่น', '015พิษณุโลก', '016บุรีรัมย์', '017นครศรีธรรมราช', '018สกลนคร', '019นครสวรรค์', '020ศรีสะเกษ', '021กำแพงเพชร', '022ร้อยเอ็ด', '023สุรินทร์', '024อุ


# %%
import matplotlib.pyplot as plt
import numpy as np

# Helper function for inline image display
def matplotlib_imshow(img, one_channel=True):
    if one_channel:
        img = img.mean(dim=0)
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if one_channel:
        plt.imshow(npimg)
    else:
        plt.imshow(np.transpose(npimg, (1, 2, 0)))

dataiter = iter(training_loader)
images, labels = next(dataiter)

# Create a grid from the images and show them
img_grid = torchvision.utils.make_grid(images)
matplotlib_imshow(img_grid, one_channel=True)

# %%
def plot_graph(history):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_figwidth(10)
    fig.suptitle("Train vs Validation")
    ax1.plot(history["train_acc"], label="Train")
    ax1.plot(history["validate_acc"], label="Validation")
    ax1.legend()
    ax1.set_title("Accuracy")

    ax2.plot(history["train_loss"], label="Train")
    ax2.plot(history["validate_loss"], label="Validation")
    ax2.legend()
    ax2.set_title("Loss")
    fig.show()

# %%
def count_model_param_flops(model=None, input_res_h = 224, input_res_w = 224, multiply_adds=True):

    prods = {}

    def save_hook(name):
        def hook_per(self, input, output):
            prods[name] = np.prod(input[0].shape)

        return hook_per

    list_1 = []

    def simple_hook(self, input, output):
        list_1.append(np.prod(input[0].shape))

    list_2 = {}

    def simple_hook2(self, input, output):
        list_2["names"] = np.prod(input[0].shape)

    list_conv = []

    def conv_hook(self, input, output):
        batch_size, input_channels, input_height, input_width = input[0].size()
        output_channels, output_height, output_width = output[0].size()

        kernel_ops = (
            self.kernel_size[0] * self.kernel_size[1] * (self.in_channels / self.groups)
        )
        bias_ops = 1 if self.bias is not None else 0

        params = output_channels * (kernel_ops + bias_ops)
        # flops = (kernel_ops * (2 if multiply_adds else 1) + bias_ops) * output_channels * output_height * output_width * batch_size

        num_weight_params = (self.weight.data != 0).float().sum()
        flops = (
            (
                num_weight_params * (2 if multiply_adds else 1)
                + bias_ops * output_channels
            )
            * output_height
            * output_width
            * batch_size
        )

        list_conv.append(flops)

    list_linear = []

    def linear_hook(self, input, output):
        batch_size = input[0].size(0) if input[0].dim() == 2 else 1

        weight_ops = self.weight.nelement() * (2 if multiply_adds else 1)
        bias_ops = self.bias.nelement()

        flops = batch_size * (weight_ops + bias_ops)
        list_linear.append(flops)

    list_bn = []

    def bn_hook(self, input, output):
        list_bn.append(input[0].nelement() * 2)

    list_relu = []

    def relu_hook(self, input, output):
        list_relu.append(input[0].nelement())

    list_pooling = []

    def pooling_hook(self, input, output):
        batch_size, input_channels, input_height, input_width = input[0].size()
        output_channels, output_height, output_width = output[0].size()

        kernel_ops = self.kernel_size * self.kernel_size
        bias_ops = 0
        params = 0
        flops = (
            (kernel_ops + bias_ops)
            * output_channels
            * output_height
            * output_width
            * batch_size
        )

        list_pooling.append(flops)

    list_upsample = []

    # For bilinear upsample
    def upsample_hook(self, input, output):
        batch_size, input_channels, input_height, input_width = input[0].size()
        output_channels, output_height, output_width = output[0].size()

        flops = output_height * output_width * output_channels * batch_size * 12
        list_upsample.append(flops)

    def foo(net):
        childrens = list(net.children())
        if not childrens:
            if isinstance(net, torch.nn.Conv2d):
                net.register_forward_hook(conv_hook)
            if isinstance(net, torch.nn.Linear):
                net.register_forward_hook(linear_hook)
            if isinstance(net, torch.nn.BatchNorm2d):
                net.register_forward_hook(bn_hook)
            if isinstance(net, torch.nn.ReLU):
                net.register_forward_hook(relu_hook)
            if isinstance(net, torch.nn.MaxPool2d) or isinstance(
                net, torch.nn.AvgPool2d
            ):
                net.register_forward_hook(pooling_hook)
            if isinstance(net, torch.nn.Upsample):
                net.register_forward_hook(upsample_hook)
            return
        for c in childrens:
            foo(c)

    if model == None:
        model = torchvision.models.alexnet()
    foo(model)
    input = Variable(
        torch.rand(3, input_res_h, input_res_w).unsqueeze(0), requires_grad=True
    )
    out = model(input)

    total_flops = (
        sum(list_conv)
        + sum(list_linear)
        + sum(list_bn)
        + sum(list_relu)
        + sum(list_pooling)
        + sum(list_upsample)
    )

    print(
        "Number of FLOPs: %.6f GFLOPs (%.2f MFLOPs)"
        % (total_flops / 1e9, total_flops / 1e6)
    )

    return total_flops

# %%
class Model(nn.Module):
    def __init__(self, num_classes=NUM_CLASSES):
        super(Model, self).__init__()
        self.model = models.mobilenet_v3_small(weights="DEFAULT")
        in_features = self.model.classifier[3].in_features
        self.model.classifier[3] = nn.Linear(in_features, num_classes)

    def forward(self, x):
        return self.model(x)


model = Model().to(device)

summary(model, (3, IMAGE_HEIGHT, IMAGE_WIDTH))
count_model_param_flops(
    model=model.to("cpu").eval(), input_res_h = IMAGE_HEIGHT, input_res_w = IMAGE_WIDTH, multiply_adds=True
)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v3_small-047dcff4.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v3_small-047dcff4.pth
# 100%|██████████| 9.83M/9.83M [00:00<00:00, 160MB/s]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 16, 37, 112]             432
#        BatchNorm2d-2          [-1, 16, 37, 112]              32
#          Hardswish-3          [-1, 16, 37, 112]               0
#             Conv2d-4           [-1, 16, 19, 56]             144
#        BatchNorm2d-5           [-1, 16, 19, 56]              32
#               ReLU-6           [-1, 16, 19, 56]               0
#  AdaptiveAvgPool2d-7             [-1, 16, 1, 1]               0
#             Conv2d-8              [-1, 8, 1, 1]             136
#               ReLU-9              [-1, 8, 1, 1]               0
#            Conv2d-10             [-1, 16, 1, 1]             144
#       Hardsigmoid-11             [-1, 16, 1, 1]               0
# SqueezeExcitation-12           [-1, 16, 19, 56]               0
#            Conv2d-13           [-1, 16, 19, 56]             256
#       BatchNorm2d-14           [-1, 16, 19, 56]              32
#  InvertedResidual-15           [-1, 16, 19, 56]               0
#            Conv2d-16           [-1, 72, 19, 56]           1,152
#       BatchNorm2d-17           [-1, 72, 19, 56]             144
#              ReLU-18           [-1, 72, 19, 56]               0
#            Conv2d-19           [-1, 72, 10, 28]             648
#       BatchNorm2d-20           [-1, 72, 10, 28]             144
#              ReLU-21           [-1, 72, 10, 28]               0
#            Conv2d-22           [-1, 24, 10, 28]           1,728
#       BatchNorm2d-23           [-1, 24, 10, 28]              48
#  InvertedResidual-24           [-1, 24, 10, 28]               0
#            Conv2d-25           [-1, 88, 10, 28]           2,112
#       BatchNorm2d-26           [-1, 88, 10, 28]             176
#              ReLU-27           [-1, 88, 10, 28]               0
#            Conv2d-28           [-1, 88, 10, 28]             792
#       BatchNorm2d-29           [-1, 88, 10, 28]             176
#              ReLU-30           [-1, 88, 10, 28]               0
#            Conv2d-31           [-1, 24, 10, 28]           2,112
#       BatchNorm2d-32           [-1, 24, 10, 28]              48
#  InvertedResidual-33           [-1, 24, 10, 28]               0
#            Conv2d-34           [-1, 96, 10, 28]           2,304
#       BatchNorm2d-35           [-1, 96, 10, 28]             192
#         Hardswish-36           [-1, 96, 10, 28]               0
#            Conv2d-37            [-1, 96, 5, 14]           2,400
#       BatchNorm2d-38            [-1, 96, 5, 14]             192
#         Hardswish-39            [-1, 96, 5, 14]               0
# AdaptiveAvgPool2d-40             [-1, 96, 1, 1]               0
#            Conv2d-41             [-1, 24, 1, 1]           2,328
#              ReLU-42             [-1, 24, 1, 1]               0
#            Conv2d-43             [-1, 96, 1, 1]           2,400
#       Hardsigmoid-44             [-1, 96, 1, 1]               0
# SqueezeExcitation-45            [-1, 96, 5, 14]               0
#            Conv2d-46            [-1, 40, 5, 14]           3,840
#       BatchNorm2d-47            [-1, 40, 5, 14]              80
#  InvertedResidual-48            [-1, 40, 5, 14]               0
#            Conv2d-49           [-1, 240, 5, 14]           9,600
#       BatchNorm2d-50           [-1, 240, 5, 14]             480
#         Hardswish-51           [-1, 240, 5, 14]               0
#            Conv2d-52           [-1, 240, 5, 14]           6,000
#       BatchNorm2d-53           [-1, 240, 5, 14]             480
#         Hardswish-54           [-1, 240, 5, 14]               0
# AdaptiveAvgPool2d-55            [-1, 240, 1, 1]               0
#            Conv2d-56             [-1, 64, 1, 1]          15,424
#              ReLU-57             [-1, 64, 1, 1]               0
#            Conv2d-58            [-1, 240, 1, 1]          15,600
#       Hardsigmoid-59            [-1, 240, 1, 1]               0
# SqueezeExcitation-60           [-1, 240, 5, 14]               0
#            Conv2d-61            [-1, 40, 5, 14]           9,600
#       BatchNorm2d-62            [-1, 40, 5, 14]              80
#  InvertedResidual-63            [-1, 40, 5, 14]               0
#            Conv2d-64           [-1, 240, 5, 14]           9,600
#       BatchNorm2d-65           [-1, 240, 5, 14]             480
#         Hardswish-66           [-1, 240, 5, 14]               0
#            Conv2d-67           [-1, 240, 5, 14]           6,000
#       BatchNorm2d-68           [-1, 240, 5, 14]             480
#         Hardswish-69           [-1, 240, 5, 14]               0
# AdaptiveAvgPool2d-70            [-1, 240, 1, 1]               0
#            Conv2d-71             [-1, 64, 1, 1]          15,424
#              ReLU-72             [-1, 64, 1, 1]               0
#            Conv2d-73            [-1, 240, 1, 1]          15,600
#       Hardsigmoid-74            [-1, 240, 1, 1]               0
# SqueezeExcitation-75           [-1, 240, 5, 14]               0
#            Conv2d-76            [-1, 40, 5, 14]           9,600
#       BatchNorm2d-77            [-1, 40, 5, 14]              80
#  InvertedResidual-78            [-1, 40, 5, 14]               0
#            Conv2d-79           [-1, 120, 5, 14]           4,800
#       BatchNorm2d-80           [-1, 120, 5, 14]             240
#         Hardswish-81           [-1, 120, 5, 14]               0
#            Conv2d-82           [-1, 120, 5, 14]           3,000
#       BatchNorm2d-83           [-1, 120, 5, 14]             240
#         Hardswish-84           [-1, 120, 5, 14]               0
# AdaptiveAvgPool2d-85            [-1, 120, 1, 1]               0
#            Conv2d-86             [-1, 32, 1, 1]           3,872
#              ReLU-87             [-1, 32, 1, 1]               0
#            Conv2d-88            [-1, 120, 1, 1]           3,960
#       Hardsigmoid-89            [-1, 120, 1, 1]               0
# SqueezeExcitation-90           [-1, 120, 5, 14]               0
#            Conv2d-91            [-1, 48, 5, 14]           5,760
#       BatchNorm2d-92            [-1, 48, 5, 14]              96
#  InvertedResidual-93            [-1, 48, 5, 14]               0
#            Conv2d-94           [-1, 144, 5, 14]           6,912
#       BatchNorm2d-95           [-1, 144, 5, 14]             288
#         Hardswish-96           [-1, 144, 5, 14]               0
#            Conv2d-97           [-1, 144, 5, 14]           3,600
#       BatchNorm2d-98           [-1, 144, 5, 14]             288
#         Hardswish-99           [-1, 144, 5, 14]               0
# AdaptiveAvgPool2d-100            [-1, 144, 1, 1]               0
#           Conv2d-101             [-1, 40, 1, 1]           5,800
#             ReLU-102             [-1, 40, 1, 1]               0
#           Conv2d-103            [-1, 144, 1, 1]           5,904
#      Hardsigmoid-104            [-1, 144, 1, 1]               0
# SqueezeExcitation-105           [-1, 144, 5, 14]               0
#           Conv2d-106            [-1, 48, 5, 14]           6,912
#      BatchNorm2d-107            [-1, 48, 5, 14]              96
# InvertedResidual-108            [-1, 48, 5, 14]               0
#           Conv2d-109           [-1, 288, 5, 14]          13,824
#      BatchNorm2d-110           [-1, 288, 5, 14]             576
#        Hardswish-111           [-1, 288, 5, 14]               0
#           Conv2d-112            [-1, 288, 3, 7]           7,200
#      BatchNorm2d-113            [-1, 288, 3, 7]             576
#        Hardswish-114            [-1, 288, 3, 7]               0
# AdaptiveAvgPool2d-115            [-1, 288, 1, 1]               0
#           Conv2d-116             [-1, 72, 1, 1]          20,808
#             ReLU-117             [-1, 72, 1, 1]               0
#           Conv2d-118            [-1, 288, 1, 1]          21,024
#      Hardsigmoid-119            [-1, 288, 1, 1]               0
# SqueezeExcitation-120            [-1, 288, 3, 7]               0
#           Conv2d-121             [-1, 96, 3, 7]          27,648
#      BatchNorm2d-122             [-1, 96, 3, 7]             192
# InvertedResidual-123             [-1, 96, 3, 7]               0
#           Conv2d-124            [-1, 576, 3, 7]          55,296
#      BatchNorm2d-125            [-1, 576, 3, 7]           1,152
#        Hardswish-126            [-1, 576, 3, 7]               0
#           Conv2d-127            [-1, 576, 3, 7]          14,400
#      BatchNorm2d-128            [-1, 576, 3, 7]           1,152
#        Hardswish-129            [-1, 576, 3, 7]               0
# AdaptiveAvgPool2d-130            [-1, 576, 1, 1]               0
#           Conv2d-131            [-1, 144, 1, 1]          83,088
#             ReLU-132            [-1, 144, 1, 1]               0
#           Conv2d-133            [-1, 576, 1, 1]          83,520
#      Hardsigmoid-134            [-1, 576, 1, 1]               0
# SqueezeExcitation-135            [-1, 576, 3, 7]               0
#           Conv2d-136             [-1, 96, 3, 7]          55,296
#      BatchNorm2d-137             [-1, 96, 3, 7]             192
# InvertedResidual-138             [-1, 96, 3, 7]               0
#           Conv2d-139            [-1, 576, 3, 7]          55,296
#      BatchNorm2d-140            [-1, 576, 3, 7]           1,152
#        Hardswish-141            [-1, 576, 3, 7]               0
#           Conv2d-142            [-1, 576, 3, 7]          14,400
#      BatchNorm2d-143            [-1, 576, 3, 7]           1,152
#        Hardswish-144            [-1, 576, 3, 7]               0
# AdaptiveAvgPool2d-145            [-1, 576, 1, 1]               0
#           Conv2d-146            [-1, 144, 1, 1]          83,088
#             ReLU-147            [-1, 144, 1, 1]               0
#           Conv2d-148            [-1, 576, 1, 1]          83,520
#      Hardsigmoid-149            [-1, 576, 1, 1]               0
# SqueezeExcitation-150            [-1, 576, 3, 7]               0
#           Conv2d-151             [-1, 96, 3, 7]          55,296
#      BatchNorm2d-152             [-1, 96, 3, 7]             192
# InvertedResidual-153             [-1, 96, 3, 7]               0
#           Conv2d-154            [-1, 576, 3, 7]          55,296
#      BatchNorm2d-155            [-1, 576, 3, 7]           1,152
#        Hardswish-156            [-1, 576, 3, 7]               0
# AdaptiveAvgPool2d-157            [-1, 576, 1, 1]               0
#           Linear-158                 [-1, 1024]         590,848
#        Hardswish-159                 [-1, 1024]               0
#          Dropout-160                 [-1, 1024]               0
#           Linear-161                   [-1, 78]          79,950
#      MobileNetV3-162                   [-1, 78]               0
# ================================================================
# Total params: 1,597,806
# Trainable params: 1,597,806
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.19
# Forward/backward pass size (MB): 12.47
# Params size (MB): 6.10
# Estimated Total Size (MB): 18.75
# ----------------------------------------------------------------
# Number of FLOPs: 0.044236 GFLOPs (44.24 MFLOPs)
# tensor(44236392.)

# %%
model = Model().to(device)
loss_fn = torch.nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)


epoch_number = 0
path_save_cp = "./"
best_vloss = 1_000_000.0
training_logs = {
    "train_loss": [],
    "train_acc": [],
    "validate_loss": [],
    "validate_acc": [],
}

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

patience = 5
min_delta = 0.001
best_vloss = float("inf")
epochs_no_improve = 0
t_0_accelerated = time.time()

for epoch in range(EPOCHS):
    train_loss, train_correct = 0, 0
    model.train(True)

    for i, data in enumerate(training_loader):
        inputs, labels = data[0].to(device), data[1].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_fn(outputs, labels)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        train_correct += (outputs.argmax(1) == labels).float().sum().item()

    training_logs["train_loss"].append(train_loss / len(training_loader))
    training_logs["train_acc"].append(train_correct / len(training_loader.dataset))

    running_vloss = 0.0
    model.eval()
    valid_loss, valid_correct = 0, 0

    with torch.no_grad():
        for i, vdata in enumerate(validation_loader):
            vinputs, vlabels = vdata[0].to(device), vdata[1].to(device)
            voutputs = model(vinputs)
            vloss = loss_fn(voutputs, vlabels)
            valid_loss += loss_fn(voutputs, vlabels).item()
            valid_correct += (voutputs.argmax(1) == vlabels).float().sum().item()

        training_logs["validate_loss"].append(valid_loss / len(validation_loader))
        training_logs["validate_acc"].append(
            valid_correct / len(validation_loader.dataset)
        )

    if epoch % 1 == 0:
        print(
            f"Epochs {epoch+1}".ljust(10),
            f"train loss {training_logs['train_loss'][-1]:.5f}",
            f"train acc {training_logs['train_acc'][-1]:.5f}",
            f"validate loss {training_logs['validate_loss'][-1]:.5f}",
            f"validate acc {training_logs['validate_acc'][-1]:.5f}",
        )
        print("-" * 80)

    if valid_loss < best_vloss - min_delta:
        best_vloss = valid_loss
        epochs_no_improve = 0
        if not os.path.exists(path_save_cp):
            os.mkdir(path_save_cp)
        model_dict = {
            'state_dict': model.state_dict(),
            'class_mapping': full_training_set.class_to_idx
        }
        torch.save(model_dict, path_save_cp + "Province_MobileNetV3Small.pth")
    else:
        epochs_no_improve += 1

    if epochs_no_improve >= patience and epoch > 50:
        print(f"Early stopping triggered after {epoch+1} epochs.")
        break

t_end_accelerated = time.time() - t_0_accelerated
print(
    f"Time consumption for accelerated CUDA training (device:{device}): {t_end_accelerated} sec"
)
# Out:
# Epochs 1   train loss 2.52557 train acc 0.40601 validate loss 7.45515 validate acc 0.14706
# --------------------------------------------------------------------------------
# Epochs 2   train loss 0.66917 train acc 0.82643 validate loss 1.17675 validate acc 0.68627
# --------------------------------------------------------------------------------
# Epochs 3   train loss 0.20886 train acc 0.94204 validate loss 0.54811 validate acc 0.84926
# --------------------------------------------------------------------------------
# Epochs 4   train loss 0.09545 train acc 0.97209 validate loss 0.42947 validate acc 0.87010
# --------------------------------------------------------------------------------
# Epochs 5   train loss 0.05623 train acc 0.98344 validate loss 0.40628 validate acc 0.89583
# --------------------------------------------------------------------------------
# Epochs 6   train loss 0.04669 train acc 0.98896 validate loss 0.42941 validate acc 0.88235
# --------------------------------------------------------------------------------
# Epochs 7   train loss 0.07164 train acc 0.97792 validate loss 0.32127 validate acc 0.91912
# --------------------------------------------------------------------------------
# Epochs 8   train loss 0.05554 train acc 0.98620 validate loss 0.30930 validate acc 0.91912
# --------------------------------------------------------------------------------
# Epochs 9   train loss 0.03378 train acc 0.99049 validate loss 0.25754 validate acc 0.94485
# --------------------------------------------------------------------------------
# Epochs 10  train loss 0.03064 train acc 0.99111 validate loss 0.33123 validate acc 0.93015
# --------------------------------------------------------------------------------
# Epochs 11  train loss 0.07315 train acc 0.97945 validate loss 0.45372 validate acc 0.87623
# --------------------------------------------------------------------------------
# Epochs 12  train loss 0.02993 train acc 0.99172 validate loss 0.29209 validate acc 0.92647
# --------------------------------------------------------------------------------
# Epochs 13  train loss 0.03744 train acc 0.98927 validate loss 0.35772 validate acc 0.92034
# --------------------------------------------------------------------------------
# Epochs 14  train loss 0.02940 train acc 0.99233 validate loss 0.33552 validate acc 0.92279
# --------------------------------------------------------------------------------
# Epochs 15  train loss 0.03994 train acc 0.98651 validate loss 0.27244 validate acc 0.93750
# --------------------------------------------------------------------------------
# Epochs 16  train loss 0.04859 train acc 0.98804 validate loss 0.27204 validate acc 0.93995
# --------------------------------------------------------------------------------
# Epochs 17  train loss 0.02683 train acc 0.99080 validate loss 0.22137 validate acc 0.93873
# --------------------------------------------------------------------------------
# Epochs 18  train loss 0.01030 train acc 0.99724 validate loss 0.14771 validate acc 0.96324
# --------------------------------------------------------------------------------
# Epochs 19  train loss 0.01288 train acc 0.99724 validate loss 0.22451 validate acc 0.94853
# --------------------------------------------------------------------------------
# Epochs 20  train loss 0.04646 train acc 0.98681 validate loss 0.25118 validate acc 0.93873
# --------------------------------------------------------------------------------
# Epochs 21  train loss 0.03870 train acc 0.98651 validate loss 0.37040 validate acc 0.91299
# --------------------------------------------------------------------------------
# Epochs 22  train loss 0.03791 train acc 0.98773 validate loss 0.35484 validate acc 0.91544
# --------------------------------------------------------------------------------
# Epochs 23  train loss 0.01787 train acc 0.99509 validate loss 0.13313 validate acc 0.96814
# --------------------------------------------------------------------------------
# Epochs 24  train loss 0.00653 train acc 0.99785 validate loss 0.12936 validate acc 0.97304
# --------------------------------------------------------------------------------
# Epochs 25  train loss 0.00810 train acc 0.99847 validate loss 0.12101 validate acc 0.97181
# --------------------------------------------------------------------------------
# Epochs 26  train loss 0.01851 train acc 0.99509 validate loss 0.24697 validate acc 0.93750
# --------------------------------------------------------------------------------
# Epochs 27  train loss 0.04867 train acc 0.98712 validate loss 0.36227 validate acc 0.92402
# --------------------------------------------------------------------------------
# Epochs 28  train loss 0.05297 train acc 0.98497 validate loss 0.36986 validate acc 0.91912
# --------------------------------------------------------------------------------
# Epochs 29  train loss 0.06477 train acc 0.98589 validate loss 0.42350 validate acc 0.91176
# --------------------------------------------------------------------------------
# Epochs 30  train loss 0.03214 train acc 0.98957 validate loss 0.25256 validate acc 0.94608
# --------------------------------------------------------------------------------
# Epochs 31  train loss 0.03374 train acc 0.98927 validate loss 0.21029 validate acc 0.95833
# --------------------------------------------------------------------------------
# Epochs 32  train loss 0.01855 train acc 0.99632 validate loss 0.14043 validate acc 0.97304
# --------------------------------------------------------------------------------
# Epochs 33  train loss 0.00435 train acc 0.99877 validate loss 0.12408 validate acc 0.97304
# --------------------------------------------------------------------------------
# Epochs 34  train loss 0.00163 train acc 0.99939 validate loss 0.09372 validate acc 0.98039
# --------------------------------------------------------------------------------
# Epochs 35  train loss 0.00516 train acc 0.99877 validate loss 0.09767 validate acc 0.97549
# --------------------------------------------------------------------------------
# Epochs 36  train loss 0.01083 train acc 0.99724 validate loss 0.14245 validate acc 0.97059
# --------------------------------------------------------------------------------
# Epochs 37  train loss 0.03238 train acc 0.99172 validate loss 0.27014 validate acc 0.95098
# --------------------------------------------------------------------------------
# Epochs 38  train loss 0.02084 train acc 0.99632 validate loss 0.16889 validate acc 0.96446
# --------------------------------------------------------------------------------
# Epochs 39  train loss 0.03081 train acc 0.99141 validate loss 0.22575 validate acc 0.94853
# --------------------------------------------------------------------------------
# Epochs 40  train loss 0.02127 train acc 0.99295 validate loss 0.20993 validate acc 0.94853
# --------------------------------------------------------------------------------
# Epochs 41  train loss 0.03008 train acc 0.99141 validate loss 0.38570 validate acc 0.91912
# --------------------------------------------------------------------------------
# Epochs 42  train loss 0.04367 train acc 0.98773 validate loss 0.27968 validate acc 0.94118
# --------------------------------------------------------------------------------
# Epochs 43  train loss 0.01884 train acc 0.99479 validate loss 0.20794 validate acc 0.96201
# --------------------------------------------------------------------------------
# Epochs 44  train loss 0.00417 train acc 0.99847 validate loss 0.16166 validate acc 0.96569
# --------------------------------------------------------------------------------
# Epochs 45  train loss 0.01852 train acc 0.99417 validate loss 0.24113 validate acc 0.94975
# --------------------------------------------------------------------------------
# Epochs 46  train loss 0.01946 train acc 0.99448 validate loss 0.37729 validate acc 0.91667
# --------------------------------------------------------------------------------
# Epochs 47  train loss 0.04114 train acc 0.98559 validate loss 0.31639 validate acc 0.92892
# --------------------------------------------------------------------------------
# Epochs 48  train loss 0.02731 train acc 0.99233 validate loss 0.14991 validate acc 0.96814
# --------------------------------------------------------------------------------
# Epochs 49  train loss 0.00861 train acc 0.99847 validate loss 0.12831 validate acc 0.97426
# --------------------------------------------------------------------------------
# Epochs 50  train loss 0.00230 train acc 0.99908 validate loss 0.12622 validate acc 0.96936
# --------------------------------------------------------------------------------
# Epochs 51  train loss 0.00091 train acc 0.99969 validate loss 0.10023 validate acc 0.97794
# --------------------------------------------------------------------------------
# Epochs 52  train loss 0.00015 train acc 1.00000 validate loss 0.09485 validate acc 0.97917
# --------------------------------------------------------------------------------
# Early stopping triggered after 52 epochs.
# Time consumption for accelerated CUDA training (device:cuda): 4707.094249486923 sec

# %%
plot_graph(training_logs)

# %%
PATH = "./Province_MobileNetV3Small.pth"
checkpoint = torch.load(PATH, map_location=torch.device("cpu"))
loaded_model = model
loaded_model.load_state_dict(checkpoint['state_dict'])
acc_test = 0
test_loss = 0
loaded_model.to(device).eval()
stored_lbs = torch.empty(0, dtype=torch.float32).to(device)
stored_preds = torch.empty(0, dtype=torch.float32).to(device)
t_0_accelerated = time.time()

with torch.no_grad():
    for i, tdata in enumerate(validation_loader):
        tinputs, tlabels = tdata[0].to(device), tdata[1].to(device)
        toutputs = loaded_model(tinputs)
        loss = loss_fn(toutputs, tlabels)
        test_loss += loss
        _, preds_t = torch.max(toutputs, 1)
        acc_test += (preds_t == tlabels).float().mean().item()
        stored_lbs = torch.cat((stored_lbs, tlabels), 0)
        stored_preds = torch.cat((stored_preds, preds_t), 0)

accuracy_t = round(acc_test / float(len(validation_loader)), 4)
avg_tloss = test_loss / (i + 1)
t_end_accelerated = time.time() - t_0_accelerated
print(
    "[(test loss: {}] [accuracy_test: {} %]".format(
        avg_tloss, accuracy_t * 100
    )
)
print(
    f"Time consumption for accelerated CUDA training (device:{device}): {t_end_accelerated} sec"
)
# Out:
# <ipython-input-15-2a3534f3436a>:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(PATH, map_location=torch.device("cpu"))
# [(test loss: 0.09372005611658096] [accuracy_test: 97.96000000000001 %]
# Time consumption for accelerated CUDA training (device:cuda): 17.468113899230957 sec

# %%
from sklearn.metrics import (
    precision_recall_fscore_support,
    normalized_mutual_info_score,
    adjusted_rand_score,
)

lb = stored_lbs.cpu()
prd = stored_preds.cpu()

# ---F1-score/Precision/Recall scores
print(
    "Precision/Recall/F-beta score:",
    precision_recall_fscore_support(
        lb, prd, average="weighted", zero_division=0, beta=1.0
    ),
)

# ---Normalized Mutual Information (NMI) score
nmi_score = normalized_mutual_info_score(
    labels_true=lb,
    labels_pred=prd,
    average_method="arithmetic",
)

# ---Rand Index (RI) score
ri_score = adjusted_rand_score(
    labels_true=lb,
    labels_pred=prd,
)

print(f"NMI score: {nmi_score}, RI score: {ri_score}")
# Out:
# Precision/Recall/F-beta score: (0.9814590230031406, 0.9803921568627451, 0.9789117816212558, None)
# NMI score: 0.9870366918860094, RI score: 0.9813522191681

# %% [markdown]
# #### onnx

# %%
# !pip install onnx
# !pip install onnxscript
# !pip install onnxruntime
# Out:
# Collecting onnx
#   Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from onnx) (1.26.4)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx) (4.25.6)
# Downloading onnx-1.17.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 69.5 MB/s eta 0:00:00
# Installing collected packages: onnx
# Successfully installed onnx-1.17.0
# Collecting onnxscript
#   Downloading onnxscript-0.2.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from onnxscript) (1.26.4)
# Requirement already satisfied: onnx>=1.16 in /usr/local/lib/python3.11/dist-packages (from onnxscript) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.11/dist-packages (from onnxscript) (4.12.2)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.11/dist-packages (from onnxscript) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxscript) (24.2)
# Requirement already satisfied: protobuf>=3.20.2 in /usr/local/lib/python3.11/dist-packages (from onnx>=1.16->onnxscript) (4.25.6)
# Downloading onnxscript-0.2.0-py3-none-any.whl (691 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 691.6/691.6 kB 34.9 MB/s eta 0:00:00
# Installing collected packages: onnxscript
# Successfully installed onnxscript-0.2.0
# Collecting onnxruntime
#   Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (24.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (4.25.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime) (1.13.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime) (1.3.0)
# Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 95.0 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.3 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 onnxruntime-1.20.1

# %%
import onnx
import onnxruntime as ort

# %%
def inspect_onnx_model(model_path):
    # Load ONNX model
    model = onnx.load(model_path)

    # Print model inputs
    print("\nModel Inputs:")
    for input in model.graph.input:
        print(f"Name: {input.name}")
        print(f"Shape: {[d.dim_value for d in input.type.tensor_type.shape.dim]}")

    # Print model outputs
    print("\nModel Outputs:")
    for output in model.graph.output:
        print(f"Name: {output.name}")
        print(f"Shape: {[d.dim_value for d in output.type.tensor_type.shape.dim]}")

    # Create an inference session to get more details
    session = ort.InferenceSession(model_path, providers=['CPUExecutionProvider'])

    print("\nDetailed Input Info:")
    for i in session.get_inputs():
        print(f"Name: {i.name}")
        print(f"Shape: {i.shape}")
        print(f"Type: {i.type}")

    print("\nDetailed Output Info:")
    for o in session.get_outputs():
        print(f"Name: {o.name}")
        print(f"Shape: {o.shape}")
        print(f"Type: {o.type}")

# %%
from PIL import Image

def test_single_image(image_path, model_path, class_mapping):
    # Initialize ONNX Runtime session
    session = ort.InferenceSession(model_path, providers=['CPUExecutionProvider'])

    image = Image.open(image_path).convert('RGB')
    image_tensor = transform(image)
    input_data = image_tensor.unsqueeze(0).numpy()

    # Run inference
    input_name = session.get_inputs()[0].name
    outputs = session.run(None, {input_name: input_data.astype(np.float32)})
    probabilities = outputs[0][0]

    # Get top predictions
    top_indices = np.argsort(probabilities)[-5:][::-1]  # Get top 5

    print("\nPredictions:")
    for idx in top_indices:
        print(f"Index {idx}: Class {[k for k,v in class_mapping.items() if v == idx][0]}, "
              f"Probability: {probabilities[idx]:.4f}")

    return probabilities

# %%
checkpoint = torch.load('Province_MobileNetV3Small.pth')
torch_model = Model()
torch_model.load_state_dict(checkpoint['state_dict'])
class_mapping = checkpoint['class_mapping']
torch_model.eval()
torch_input = torch.randn(1, 3, IMAGE_HEIGHT, IMAGE_WIDTH)

input_names = ["input"]
output_names = ["output"]
dynamic_axes = {"input": {0: "batch_size"}, "output": {0: "batch_size"}}

torch.onnx.export(torch_model,
                  torch_input,
                  "Province_MobileNetV3Small.onnx",
                  export_params=True,
                  opset_version=14,
                  do_constant_folding=False,
                  input_names=input_names,
                  output_names=output_names,
                  dynamic_axes=dynamic_axes,
                  keep_initializers_as_inputs=False,
                  )
# Out:
# <ipython-input-21-47619025c751>:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('Province_MobileNetV3Small.pth')

# %%
session = ort.InferenceSession("Province_MobileNetV3Small.onnx", providers=['CPUExecutionProvider'])

input_name = session.get_inputs()[0].name
dummy_input = np.random.randn(1, 3, IMAGE_HEIGHT, IMAGE_WIDTH).astype(np.float32)

# Warmup run
session.run(None, {input_name: dummy_input})

# Benchmark
num_runs = 1000
start_time = time.time()
for _ in range(num_runs):
    output = session.run(None, {input_name: dummy_input})
end_time = time.time()

avg_inference_time = (end_time - start_time) / num_runs
fps = 1 / avg_inference_time

print(f"Average Inference Time on CPU: {avg_inference_time * 1000:.2f} ms")
print(f"FPS (Frames Per Second): {fps:.2f}")
# Out:
# Average Inference Time on CPU: 3.21 ms
# FPS (Frames Per Second): 311.55

# %%
model_path = "Province_MobileNetV3Small.onnx"
inspect_onnx_model(model_path)
# Out:
# Model Inputs:
# Name: input
# Shape: [0, 3, 74, 224]
#
# Model Outputs:
# Name: output
# Shape: [0, 78]
#
# Detailed Input Info:
# Name: input
# Shape: ['batch_size', 3, 74, 224]
# Type: tensor(float)
#
# Detailed Output Info:
# Name: output
# Shape: ['batch_size', 78]
# Type: tensor(float)

# %%
# Test with a known image
test_single_image('./drive/MyDrive/test/24_02_05_V00490_Province.png', 'Province_MobileNetV3Small.onnx', class_mapping)
# Out:
# Predictions:
# Index 68: Class 068กรุงเทพมหานคร, Probability: 19.3822
# Index 62: Class 062พระนครศรีอยุธยา, Probability: 5.0215
# Index 21: Class 021กำแพงเพชร, Probability: 3.6518
# Index 31: Class 031ประจวบคีรีขันธ์, Probability: 3.3317
# Index 76: Class 076สมุทรสงคราม, Probability: 0.4660
# array([ -5.92134   , -15.657245  ,  -1.7652256 , -10.296349  ,
#         -9.902946  ,  -3.769127  ,  -8.261633  ,  -7.638647  ,
#         -0.77830464,  -9.406474  , -16.13812   , -15.546758  ,
#         -5.956758  , -14.508391  ,  -6.304413  ,  -8.28398   ,
#         -8.60303   ,  -2.0185118 ,  -5.570036  ,  -6.5874434 ,
#         -3.5305367 ,   3.651767  ,  -7.6408463 ,  -0.4434657 ,
#        -11.942899  , -10.769167  ,  -6.1701865 , -10.629944  ,
#        -15.70699   , -11.694758  , -10.9065895 ,   3.3316631 ,
#         -2.4546432 ,  -5.989803  ,  -7.7184496 , -11.551409  ,
#         -2.633533  ,  -5.733534  ,  -3.959581  ,  -1.2537826 ,
#         -2.2694845 ,  -6.2631645 ,  -9.51704   , -10.451824  ,
#        -15.7883    ,  -5.5060225 , -14.751487  , -17.375772  ,
#         -9.46411   ,  -8.312417  , -10.037951  , -15.903842  ,
#        -13.288931  , -13.203665  ,  -5.9203014 , -14.867441  ,
#         -7.4757886 ,  -9.923104  ,  -5.606634  ,  -6.763752  ,
#         -9.584709  ,  -9.515818  ,   5.0214834 , -12.714591  ,
#         -4.40145   , -16.690466  ,  -3.693262  , -19.27236   ,
#         19.382236  ,  -8.064309  ,  -0.19963902,  -8.652946  ,
#         -2.7261684 , -10.738719  ,  -4.336236  ,  -7.1212034 ,
#          0.4659642 , -18.384499  ], dtype=float32)
